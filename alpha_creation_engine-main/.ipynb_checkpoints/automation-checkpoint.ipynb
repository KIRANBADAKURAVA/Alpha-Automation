# %%
import ace_lib as ace
import helpful_functions as hf
import pandas as pd
import requests
import plotly.express as px

# %%
s = ace.start_session()

# %%
datafields_df = hf.get_datafields(s, region="GLB", universe="MINVOL1M", delay=1) # by default we load all datasets USA TOP3000 delay 1
len(datafields_df.head()) # DataFrame.head() shows first 5 rows of the dataframe

# %%
datafields_df_vector = datafields_df[datafields_df["type"] == "VECTOR"]
datafields_df_matrix = datafields_df[datafields_df["type"] == "MATRIX"]

# Sort datafields by alphaCount in descending order
datafields_df_matrix = datafields_df_matrix.sort_values(by="alphaCount", ascending=False)
datafields_df_vector = datafields_df_vector.sort_values(by="alphaCount", ascending=False)

# Display the length of each datafield type
print(len(datafields_df_vector))
print(len(datafields_df_matrix))
# Out:
# 1163
# 8640

# %%
li = datafields_df_matrix.id.values.tolist()
len(li)

# %%
expressions = [
   "-ts_rank(ts_decay_exp_window({},252),252)+ts_rank(oth176_lmt_close_eq_score,252) "
    
  
]

# %%
count = 0
for i in li:
    for expr in expressions:
        try:
            count = count + 1
            print(count)
            
            simulate_data = {
                "type": "REGULAR",
                "settings": {
                    "instrumentType": "EQUITY",
                    "region": "GLB",
                    "universe": "MINVOL1M",
                    "delay": 1,
                    "decay": 0,
                    "neutralization": "SUBINDUSTRY",
                    "truncation": 0.08,
                    "pasteurization": "ON",
                    "unitHandling": "VERIFY",
                    "nanHandling": "OFF",
                    "language": "FASTEXPR",
                    "visualization": False
                },
                "regular": expr.format(i)
            }
            
            simulate_response = s.post('https://api.worldquantbrain.com/simulations', json=simulate_data)
            print(simulate_data)
            print(simulate_response)
    
            
            simulation_progress_url = simulate_response.headers['Location']
            print(simulation_progress_url)
            finished = False
            
            while True:
                simulation_progress = s.get(simulation_progress_url)
              
                print('x')
                if simulation_progress.headers.get("Retry-After", 0) == 0:
                    break
                sleep(float(simulation_progress.headers["Retry-After"]))
                
        except Exception as e:
            print(e)
# Out:
# 1
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(returns,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [201]>
# https://api.worldquantbrain.com/simulations/2bqsKO3cm4XzbaW1eDy6EhUM
# x
# name 'sleep' is not defined
# 2
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(close,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [201]>
# https://api.worldquantbrain.com/simulations/UBV6i4va55UbY616Qptw3e0
# x
# name 'sleep' is not defined
# 3
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(volume,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [201]>
# https://api.worldquantbrain.com/simulations/183gDVbPy4Wscyw3cRV6igV
# x
# name 'sleep' is not defined
# 4
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(cap,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [201]>
# https://api.worldquantbrain.com/simulations/2Gfncuc9Y53qaZYywAIABNm
# x
# name 'sleep' is not defined
# 5
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(oth176_lmt_close_eq_score,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [201]>
# https://api.worldquantbrain.com/simulations/2gbwtm8Xt4GXaWK1aqjQICDM
# x
# name 'sleep' is not defined
# 6
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(adv20,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [201]>
# https://api.worldquantbrain.com/simulations/1Lbw3Z2x14K5b8dCoJrv5BJ
# x
# name 'sleep' is not defined
# 7
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(open,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [201]>
# https://api.worldquantbrain.com/simulations/bqEW3bfo4CcbZsWcHArR86
# x
# name 'sleep' is not defined
# 8
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(high,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [201]>
# https://api.worldquantbrain.com/simulations/4xholsbgL4k5bPI4BK4vyJf
# x
# name 'sleep' is not defined
# 9
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(low,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [201]>
# https://api.worldquantbrain.com/simulations/30E5yIgAJ59l9Zzt6HBmYU8
# x
# name 'sleep' is not defined
# 10
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(sharesout,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [201]>
# https://api.worldquantbrain.com/simulations/22p4c6cKv4Cbczt625OPDem
# x
# name 'sleep' is not defined
# 11
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(vwap,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 12
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(mdl26_market_cap_u,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 13
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(mdl110_score,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 14
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(split,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 15
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(oth176_malta_eq_score,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 16
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(oth176_maltahc_eq_score,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 17
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(dividend,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 18
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(mdl110_growth,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 19
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(mdl110_analyst_sentiment,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 20
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(oth176_eq_hedge,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 21
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(oth176_lmt_open_eq_score,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 22
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(oth176_hc_eq_hedge,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 23
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(oth176_eq_medium,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 24
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(rsk70_mfm2_gemtrd_anlystsn,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 25
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(oth176_hc_eq_medium,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 26
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(oth176_hc_eq_mktcap,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 27
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(mdl110_value,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 28
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(oth176_hc_eq_seasonality,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 29
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(mdl110_price_momentum_reversal,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 30
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(mdl26_market_cap_l,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 31
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(oth176_eq_seasonality,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 32
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(mdl110_quality,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 33
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(oth176_eq_mktcap,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 34
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(oth176_malta_eq_sector,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 35
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(oth176_hc_eq_short,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 36
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(oth176_close_eq_cap,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 37
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(mdl110_alternative,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 38
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(oth176_eq_short,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 39
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(star_val_industry_rank,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 40
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(mdl110_tree,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 41
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(oth176_maltahc_eq_sector,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 42
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(oth176_open_eq_cap,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 43
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(star_val_piv_industry_rank,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 44
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(oth176_lmt_open_eq_sector,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 45
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(oth176_lmt_close_eq_sector,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 46
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(rsk70_mfm2_gemtrd_srtindcnt,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 47
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(star_val_sector_rank,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 48
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(rsk70_mfm2_gemtrd_dsrt,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 49
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(rsk70_mfm2_gemtrd_season,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 50
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(mdl38_rel_val_global_rk,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 51
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(star_eps_surprise_prediction_fy1,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 52
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(star_val_region_rank,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 53
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(star_eps_surprise_prediction_12m,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 54
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(mdl77_ttmaccu,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 55
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(oth460_clv_class,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 56
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(star_arm_global_rank,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 57
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(mdl77_global_pfcfmtt,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 58
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(mdl77_vefcfmtt,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 59
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(star_arm_country_rank,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 60
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(rsk70_mfm2_gemtrd_shortint,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 61
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(star_eps_surprise_prediction_fy2,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 62
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(mdl77_curindfcfp_,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 63
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(rsk70_mfm2_gemtrd_ltrevrsl,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 64
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(star_arm_pref_earnings_score,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 65
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(anl15_gr_12_m_1m_chg,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 66
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(mdl26_yld_stm_fy1_rnngs,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 67
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(mdl26_ep_industry_percentile_fy1,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 68
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(star_val_piv_sector_rank,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 69
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(star_val_piv_ratio,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 70
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(star_eps_surprise_prediction_fq1,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 71
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(star_eps_smart_estimate_12m,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 72
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(mdl38_iv_warranted_f12m_p_e,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 73
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(star_arm_revenue_score,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 74
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(fnd23_annfvmfm2_fcos,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 75
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(oth460_3l_vlc,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 76
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(star_val_piv_region_rank,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 77
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(mdl77_curindocfp_,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 78
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(star_eps_smart_estimate_fy1,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 79
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(mdl77_all_delay_1_ttmaccu,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 80
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(mdl38_rel_val_ev_ebitda,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 81
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(anl69_cpss_best_eeps_nxt_yr,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 82
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(mdl77_mpnghc,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 83
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(star_eps_smart_estimate_fq1,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 84
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(oth460_1l_ccns,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 85
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(star_eps_smart_estimate_fy2,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 86
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(rsk70_mfm2_gemtrd_earnyild,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 87
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(mdl77_chgnoa,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 88
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(mdl26_ep_yield_smartestimate_fy1,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 89
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(scl12_buzz,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 90
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(mdl26_surprise_last_q_earnings,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 91
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(mdl26_ep_sector_percentile_fy1,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 92
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(star_val_pe,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 93
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(mdl26_yld_ndstry_prcntl_fy1_rnngs,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 94
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(oth460_1l_1dls,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 95
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(mdl26_days_since_last_report,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 96
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(star_arm_recommendations_score,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 97
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(star_eps_surprise_prediction_fq2,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 98
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(rsk70_mfm2_gemtrd_divyild,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 99
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(oth460_1l_vlc,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 100
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(star_eps_analyst_number_fq1,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 101
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(star_arm_rec_mean_prior7,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 102
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(mdl26_blndd_grwth_rt_smrtstmt,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 103
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(mdl77_sighc,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 104
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(mdl77_yoychgaa,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 105
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(mdl77_all_delay_1_mpnghc,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 106
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(mdl77_global_indrelrtn5d_,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# ...
# <Response [429]>
# 'location'
# 336
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(anl15_gr_12_m_ests_dn,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 337
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(star_val_dividend_projection_fy2,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 338
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(mdl250_maltahc_eq_score,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 339
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(mdl77_global_all_delay_1_tobinq,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 340
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(anl15_gr_18_m_1m_chg,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 341
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(mdl26_lt_grwth_ndstry_prcntl,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 342
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(mdl77_curindep_,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 343
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(anl69_ebit_best_eeps_cur_yr,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 344
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(mdl77_global_all_delay_1_fc_numrevy1,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 345
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(star_pm_midterm,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 346
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(mdl26_prsprise_fq1_earnings,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 347
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(oth460_es_ebitda_fy1_d1m_class,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 348
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(mdl77_ocfmargin,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 349
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(fnd28_a_value_08316,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 350
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(mdl26_dff_frm_50dy_mvng_vrg,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 351
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(rsk70_mfm2_gemtrd_invsqlty,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 352
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(mdl77_all_delay_1_ocfroi,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 353
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(fnd17_fcfmtt,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 354
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(mdl77_3_oilprice,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 355
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(pv53_beta_ray,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 356
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(star_val_earnings_projection_fy13,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 357
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(anl69_roes_expected_report_dt,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 358
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(mdl77_ratrev6m,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 359
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(oth460_1l_ompd,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 360
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(mdl77_global_curinddivp_,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 361
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(oth460_1l_qacr,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 362
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(mdl77_all_delay_1_fc_dypeg,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 363
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(anl39_cursharesoutstanding,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 364
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(star_val_earnings_projection_fy3,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 365
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(oth460_1l_abpo,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 366
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(oth460_3l_rw,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 367
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(anl69_ndebt_best_eeps_cur_yr,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 368
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(star_pm_industry,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 369
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(oth460_1l_21aeclg,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 370
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SUBINDUSTRY', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False}, 'regular': '-ts_rank(ts_decay_exp_window(anl69_cpss_best_cur_fiscal_year_period,252),252)+ts_rank(oth176_lmt_close_eq_score,252) '}
# <Response [429]>
# 'location'
# 371
