# %%
import pandas as pd
import requests
import json
import os
import getpass
from pathlib import Path
import sqlite3
from time import sleep
import helpful_functions as hf
import ace_lib as ace
import pickle

# %%
s = ace.start_session()
# Out:
# Complete biometrics authentication and press any key to continue:
# https://api.worldquantbrain.com/authentication/persona?inquiry=inq_btj11oHUed2WgJua233idS2rnrL7

# %%
dataset_id="fundamental28"
datafields_df = hf.get_datafields(s, region="GLB",dataset_id=dataset_id, universe="MINVOL1M", delay=1) # by default we load all datasets USA TOP3000 delay 1
len(datafields_df) # DataFrame.head() shows first 5 rows of the dataframe
# Out:
# 929

# %%
datafields_df_vector = datafields_df[datafields_df["type"] == "VECTOR"]
datafields_df_matrix = datafields_df[datafields_df["type"] == "MATRIX"]

# Sort datafields by alphaCount in descending order
datafields_df_matrix = datafields_df_matrix.sort_values(by="alphaCount", ascending=False)
datafields_df_vector = datafields_df_vector.sort_values(by="alphaCount", ascending=False)

# Display the length of each datafield type
print(len(datafields_df_vector))
print(len(datafields_df_matrix))
# Out:
# 0
# 929

# %%
li = datafields_df_matrix.id.values.tolist()
li.reverse()
len(li)
# Out:
# 929

# %%
li=

# %%
expressions = [
   "-rank(ts_rank(mdl26_peg_smartestimate_fy1,3822))-ts_rank(ts_decay_exp_window({},3822),3822) "
]

# %%
count = 0
for i in li:
    for expr in expressions:
        try:
            count = count + 1
            print(count)
            if(count<0) : continue;
            
            simulate_data = {
                "type": "REGULAR",
                "settings": {
                    "instrumentType": "EQUITY",
                    "region": "GLB",
                    "universe": "MINVOL1M",
                    "delay": 1,
                    "decay": 0,
                    "neutralization": "SECTOR",
                    "truncation": 0.08,
                    "pasteurization": "ON",
                    "unitHandling": "VERIFY",
                    "nanHandling": "OFF",
                    "language": "FASTEXPR",
                    "visualization": False,
                    "testPeriod": "P2Y0M"
                },
                "regular": expr.format(i)
            }
            
            simulate_response = s.post('https://api.worldquantbrain.com/simulations', json=simulate_data)
            print(simulate_data)
            print(simulate_response)
    
            
            simulation_progress_url = simulate_response.headers['Location']
            print(simulation_progress_url)
            finished = False
            
            while True:
                simulation_progress = s.get(simulation_progress_url)
              
                print('simulation_progress')
                if simulation_progress.headers.get("Retry-After", 0) == 0:
                    break
                sleep(float(simulation_progress.headers["Retry-After"]))
                
        except Exception as e:
            print(e)
# Out:
# 1
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SECTOR', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False, 'testPeriod': 'P2Y0M'}, 'regular': '-rank(ts_rank(mdl26_peg_smartestimate_fy1,3822))-ts_rank(ts_decay_exp_window(fnd28_nddq1_value_01051q,3822),3822) '}
# <Response [201]>
# https://api.worldquantbrain.com/simulations/4695HteFZ4R3a6BiKPSHAxu
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# 2
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SECTOR', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False, 'testPeriod': 'P2Y0M'}, 'regular': '-rank(ts_rank(mdl26_peg_smartestimate_fy1,3822))-ts_rank(ts_decay_exp_window(fnd28_value_07270q,3822),3822) '}
# <Response [201]>
# https://api.worldquantbrain.com/simulations/27JLNp1Js4BNbRX17T1qZQz8
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# 3
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SECTOR', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False, 'testPeriod': 'P2Y0M'}, 'regular': '-rank(ts_rank(mdl26_peg_smartestimate_fy1,3822))-ts_rank(ts_decay_exp_window(fnd28_nddq1_value_03245q,3822),3822) '}
# <Response [201]>
# https://api.worldquantbrain.com/simulations/27IV6I7HE5bJbo5lLo5W24x
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# 4
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SECTOR', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False, 'testPeriod': 'P2Y0M'}, 'regular': '-rank(ts_rank(mdl26_peg_smartestimate_fy1,3822))-ts_rank(ts_decay_exp_window(fnd28_nddq1_value_03351q,3822),3822) '}
# <Response [201]>
# https://api.worldquantbrain.com/simulations/2Enout32Z4qQb5hd9uKrR3F
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# 5
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SECTOR', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False, 'testPeriod': 'P2Y0M'}, 'regular': '-rank(ts_rank(mdl26_peg_smartestimate_fy1,3822))-ts_rank(ts_decay_exp_window(fnd28_nddq1_value_03426q,3822),3822) '}
# <Response [201]>
# https://api.worldquantbrain.com/simulations/44TH4i2Uz4ZT9J8IfJvAXVw
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# 6
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SECTOR', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False, 'testPeriod': 'P2Y0M'}, 'regular': '-rank(ts_rank(mdl26_peg_smartestimate_fy1,3822))-ts_rank(ts_decay_exp_window(fnd28_nddq1_value_03451q,3822),3822) '}
# <Response [201]>
# https://api.worldquantbrain.com/simulations/Zcp9T5gv4s395a142LjY4Ij
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# 7
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SECTOR', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False, 'testPeriod': 'P2Y0M'}, 'regular': '-rank(ts_rank(mdl26_peg_smartestimate_fy1,3822))-ts_rank(ts_decay_exp_window(fnd28_value_05450,3822),3822) '}
# <Response [201]>
# https://api.worldquantbrain.com/simulations/2uf4a93et4Qz9FR129XnUSf0
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# 8
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SECTOR', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False, 'testPeriod': 'P2Y0M'}, 'regular': '-rank(ts_rank(mdl26_peg_smartestimate_fy1,3822))-ts_rank(ts_decay_exp_window(fnd28_value_05401q,3822),3822) '}
# <Response [201]>
# https://api.worldquantbrain.com/simulations/2Y6WM36Q74BGbCx1cJJnwuB1
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# 9
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SECTOR', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False, 'testPeriod': 'P2Y0M'}, 'regular': '-rank(ts_rank(mdl26_peg_smartestimate_fy1,3822))-ts_rank(ts_decay_exp_window(fnd28_value_05376q,3822),3822) '}
# <Response [201]>
# https://api.worldquantbrain.com/simulations/1kDJ7Ka004y6bAR11SOhfOJG
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# 10
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SECTOR', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False, 'testPeriod': 'P2Y0M'}, 'regular': '-rank(ts_rank(mdl26_peg_smartestimate_fy1,3822))-ts_rank(ts_decay_exp_window(fnd28_nddq1_value_03499q,3822),3822) '}
# <Response [201]>
# https://api.worldquantbrain.com/simulations/166NXf69w52pa9zJbaO0eqn
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# 11
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SECTOR', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False, 'testPeriod': 'P2Y0M'}, 'regular': '-rank(ts_rank(mdl26_peg_smartestimate_fy1,3822))-ts_rank(ts_decay_exp_window(fnd28_nddq1_value_03506q,3822),3822) '}
# <Response [201]>
# https://api.worldquantbrain.com/simulations/4yMzSsdmB5aLaQi1dDRuUsRV
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# 12
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SECTOR', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False, 'testPeriod': 'P2Y0M'}, 'regular': '-rank(ts_rank(mdl26_peg_smartestimate_fy1,3822))-ts_rank(ts_decay_exp_window(fnd28_nddq1_value_03998q,3822),3822) '}
# <Response [201]>
# https://api.worldquantbrain.com/simulations/3qGgkZ6cw4BHbcSUqxUwyfz
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# 13
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SECTOR', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False, 'testPeriod': 'P2Y0M'}, 'regular': '-rank(ts_rank(mdl26_peg_smartestimate_fy1,3822))-ts_rank(ts_decay_exp_window(fnd28_value_05194q,3822),3822) '}
# <Response [201]>
# https://api.worldquantbrain.com/simulations/iIpUU1wA4wfazRWGCCzZOC
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# 14
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SECTOR', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False, 'testPeriod': 'P2Y0M'}, 'regular': '-rank(ts_rank(mdl26_peg_smartestimate_fy1,3822))-ts_rank(ts_decay_exp_window(fnd28_nddq1_value_04050q,3822),3822) '}
# <Response [201]>
# https://api.worldquantbrain.com/simulations/3oIESi7iY5bh9XeXjKTX04z
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# simulation_progress
# ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# 15
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SECTOR', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False, 'testPeriod': 'P2Y0M'}, 'regular': '-rank(ts_rank(mdl26_peg_smartestimate_fy1,3822))-ts_rank(ts_decay_exp_window(fnd28_nddq1_value_04053q,3822),3822) '}
# <Response [401]>
# 'location'
# 16
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SECTOR', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False, 'testPeriod': 'P2Y0M'}, 'regular': '-rank(ts_rank(mdl26_peg_smartestimate_fy1,3822))-ts_rank(ts_decay_exp_window(fnd28_nddq1_value_03101q,3822),3822) '}
# <Response [401]>
# 'location'
# 17
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SECTOR', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False, 'testPeriod': 'P2Y0M'}, 'regular': '-rank(ts_rank(mdl26_peg_smartestimate_fy1,3822))-ts_rank(ts_decay_exp_window(fnd28_nddq1_value_04057q,3822),3822) '}
# <Response [401]>
# 'location'
# 18
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SECTOR', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False, 'testPeriod': 'P2Y0M'}, 'regular': '-rank(ts_rank(mdl26_peg_smartestimate_fy1,3822))-ts_rank(ts_decay_exp_window(fnd28_nddq1_value_04301q,3822),3822) '}
# <Response [401]>
# 'location'
# 19
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SECTOR', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False, 'testPeriod': 'P2Y0M'}, 'regular': '-rank(ts_rank(mdl26_peg_smartestimate_fy1,3822))-ts_rank(ts_decay_exp_window(fnd28_nddq1_value_04401q,3822),3822) '}
# <Response [401]>
# 'location'
# 20
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SECTOR', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False, 'testPeriod': 'P2Y0M'}, 'regular': '-rank(ts_rank(mdl26_peg_smartestimate_fy1,3822))-ts_rank(ts_decay_exp_window(fnd28_nddq1_value_04440q,3822),3822) '}
# <Response [401]>
# 'location'
# 21
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SECTOR', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False, 'testPeriod': 'P2Y0M'}, 'regular': '-rank(ts_rank(mdl26_peg_smartestimate_fy1,3822))-ts_rank(ts_decay_exp_window(fnd28_value_05007,3822),3822) '}
# <Response [401]>
# 'location'
# 22
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SECTOR', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False, 'testPeriod': 'P2Y0M'}, 'regular': '-rank(ts_rank(mdl26_peg_smartestimate_fy1,3822))-ts_rank(ts_decay_exp_window(fnd28_nddq1_value_04446q,3822),3822) '}
# <Response [401]>
# 'location'
# 23
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SECTOR', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False, 'testPeriod': 'P2Y0M'}, 'regular': '-rank(ts_rank(mdl26_peg_smartestimate_fy1,3822))-ts_rank(ts_decay_exp_window(fnd28_nddq1_value_04551q,3822),3822) '}
# <Response [401]>
# 'location'
# 24
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SECTOR', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False, 'testPeriod': 'P2Y0M'}, 'regular': '-rank(ts_rank(mdl26_peg_smartestimate_fy1,3822))-ts_rank(ts_decay_exp_window(fnd28_bdea_value_18854a,3822),3822) '}
# <Response [401]>
# 'location'
# 25
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SECTOR', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False, 'testPeriod': 'P2Y0M'}, 'regular': '-rank(ts_rank(mdl26_peg_smartestimate_fy1,3822))-ts_rank(ts_decay_exp_window(fnd28_value_04225q,3822),3822) '}
# <Response [401]>
# 'location'
# 26
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SECTOR', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False, 'testPeriod': 'P2Y0M'}, 'regular': '-rank(ts_rank(mdl26_peg_smartestimate_fy1,3822))-ts_rank(ts_decay_exp_window(fnd28_nddq1_value_04701q,3822),3822) '}
# <Response [401]>
# 'location'
# 27
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SECTOR', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False, 'testPeriod': 'P2Y0M'}, 'regular': '-rank(ts_rank(mdl26_peg_smartestimate_fy1,3822))-ts_rank(ts_decay_exp_window(fnd28_value_04056q,3822),3822) '}
# <Response [401]>
# 'location'
# 28
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SECTOR', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False, 'testPeriod': 'P2Y0M'}, 'regular': '-rank(ts_rank(mdl26_peg_smartestimate_fy1,3822))-ts_rank(ts_decay_exp_window(fnd28_value_04055q,3822),3822) '}
# <Response [401]>
# 'location'
# 29
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SECTOR', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False, 'testPeriod': 'P2Y0M'}, 'regular': '-rank(ts_rank(mdl26_peg_smartestimate_fy1,3822))-ts_rank(ts_decay_exp_window(fnd28_value_04054q,3822),3822) '}
# <Response [401]>
# 'location'
# 30
# ...
# <Response [401]>
# 'location'
# 897
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SECTOR', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False, 'testPeriod': 'P2Y0M'}, 'regular': '-rank(ts_rank(mdl26_peg_smartestimate_fy1,3822))-ts_rank(ts_decay_exp_window(fnd28_astut_value_08411a,3822),3822) '}
# <Response [401]>
# 'location'
# 898
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SECTOR', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False, 'testPeriod': 'P2Y0M'}, 'regular': '-rank(ts_rank(mdl26_peg_smartestimate_fy1,3822))-ts_rank(ts_decay_exp_window(fnd28_bsassetq_value_02501q,3822),3822) '}
# <Response [401]>
# 'location'
# 899
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SECTOR', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False, 'testPeriod': 'P2Y0M'}, 'regular': '-rank(ts_rank(mdl26_peg_smartestimate_fy1,3822))-ts_rank(ts_decay_exp_window(fnd28_wsannualstats_value_08311,3822),3822) '}
# <Response [401]>
# 'location'
# 900
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SECTOR', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False, 'testPeriod': 'P2Y0M'}, 'regular': '-rank(ts_rank(mdl26_peg_smartestimate_fy1,3822))-ts_rank(ts_decay_exp_window(fnd28_fsq1_value_01701q,3822),3822) '}
# <Response [401]>
# 'location'
# 901
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SECTOR', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False, 'testPeriod': 'P2Y0M'}, 'regular': '-rank(ts_rank(mdl26_peg_smartestimate_fy1,3822))-ts_rank(ts_decay_exp_window(fnd28_wcnddq1_value_04860q,3822),3822) '}
# <Response [401]>
# 'location'
# 902
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SECTOR', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False, 'testPeriod': 'P2Y0M'}, 'regular': '-rank(ts_rank(mdl26_peg_smartestimate_fy1,3822))-ts_rank(ts_decay_exp_window(fnd28_statisticsa_value_05509a,3822),3822) '}
# <Response [401]>
# 'location'
# 903
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SECTOR', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False, 'testPeriod': 'P2Y0M'}, 'regular': '-rank(ts_rank(mdl26_peg_smartestimate_fy1,3822))-ts_rank(ts_decay_exp_window(fnd28_wsannualstats_value_05502,3822),3822) '}
# <Response [401]>
# 'location'
# 904
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SECTOR', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False, 'testPeriod': 'P2Y0M'}, 'regular': '-rank(ts_rank(mdl26_peg_smartestimate_fy1,3822))-ts_rank(ts_decay_exp_window(fnd28_value_18310q,3822),3822) '}
# <Response [401]>
# 'location'
# 905
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SECTOR', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False, 'testPeriod': 'P2Y0M'}, 'regular': '-rank(ts_rank(mdl26_peg_smartestimate_fy1,3822))-ts_rank(ts_decay_exp_window(fnd28_nddq2_value_18150q,3822),3822) '}
# <Response [401]>
# 'location'
# 906
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SECTOR', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False, 'testPeriod': 'P2Y0M'}, 'regular': '-rank(ts_rank(mdl26_peg_smartestimate_fy1,3822))-ts_rank(ts_decay_exp_window(fnd28_wcishtq_value_01706q,3822),3822) '}
# <Response [401]>
# 'location'
# 907
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SECTOR', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False, 'testPeriod': 'P2Y0M'}, 'regular': '-rank(ts_rank(mdl26_peg_smartestimate_fy1,3822))-ts_rank(ts_decay_exp_window(fnd28_levliqa_value_08116a,3822),3822) '}
# <Response [401]>
# 'location'
# 908
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SECTOR', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False, 'testPeriod': 'P2Y0M'}, 'regular': '-rank(ts_rank(mdl26_peg_smartestimate_fy1,3822))-ts_rank(ts_decay_exp_window(fnd28_wsannualstats_value_05507,3822),3822) '}
# <Response [401]>
# 'location'
# 909
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SECTOR', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False, 'testPeriod': 'P2Y0M'}, 'regular': '-rank(ts_rank(mdl26_peg_smartestimate_fy1,3822))-ts_rank(ts_decay_exp_window(fnd28_wcannuala_value_08321,3822),3822) '}
# <Response [401]>
# 'location'
# 910
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SECTOR', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False, 'testPeriod': 'P2Y0M'}, 'regular': '-rank(ts_rank(mdl26_peg_smartestimate_fy1,3822))-ts_rank(ts_decay_exp_window(fnd28_value_18265q,3822),3822) '}
# <Response [401]>
# 'location'
# 911
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SECTOR', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False, 'testPeriod': 'P2Y0M'}, 'regular': '-rank(ts_rank(mdl26_peg_smartestimate_fy1,3822))-ts_rank(ts_decay_exp_window(fnd28_astut_value_08141a,3822),3822) '}
# <Response [401]>
# 'location'
# 912
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SECTOR', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False, 'testPeriod': 'P2Y0M'}, 'regular': '-rank(ts_rank(mdl26_peg_smartestimate_fy1,3822))-ts_rank(ts_decay_exp_window(fnd28_wcfsq1_value_01706q,3822),3822) '}
# <Response [401]>
# 'location'
# 913
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SECTOR', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False, 'testPeriod': 'P2Y0M'}, 'regular': '-rank(ts_rank(mdl26_peg_smartestimate_fy1,3822))-ts_rank(ts_decay_exp_window(fnd28_bsassetq_value_02005q,3822),3822) '}
# <Response [401]>
# 'location'
# 914
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SECTOR', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False, 'testPeriod': 'P2Y0M'}, 'regular': '-rank(ts_rank(mdl26_peg_smartestimate_fy1,3822))-ts_rank(ts_decay_exp_window(fnd28_astut_value_08406a,3822),3822) '}
# <Response [401]>
# 'location'
# 915
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SECTOR', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False, 'testPeriod': 'P2Y0M'}, 'regular': '-rank(ts_rank(mdl26_peg_smartestimate_fy1,3822))-ts_rank(ts_decay_exp_window(fnd28_a_value_08631,3822),3822) '}
# <Response [401]>
# 'location'
# 916
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SECTOR', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False, 'testPeriod': 'P2Y0M'}, 'regular': '-rank(ts_rank(mdl26_peg_smartestimate_fy1,3822))-ts_rank(ts_decay_exp_window(fnd28_bdea_value_18281a,3822),3822) '}
# <Response [401]>
# 'location'
# 917
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SECTOR', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False, 'testPeriod': 'P2Y0M'}, 'regular': '-rank(ts_rank(mdl26_peg_smartestimate_fy1,3822))-ts_rank(ts_decay_exp_window(fnd28_stpera_value_09521a,3822),3822) '}
# <Response [401]>
# 'location'
# 918
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SECTOR', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False, 'testPeriod': 'P2Y0M'}, 'regular': '-rank(ts_rank(mdl26_peg_smartestimate_fy1,3822))-ts_rank(ts_decay_exp_window(fnd28_a_value_08381,3822),3822) '}
# <Response [401]>
# 'location'
# 919
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SECTOR', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False, 'testPeriod': 'P2Y0M'}, 'regular': '-rank(ts_rank(mdl26_peg_smartestimate_fy1,3822))-ts_rank(ts_decay_exp_window(fnd28_astut_value_08136a,3822),3822) '}
# <Response [401]>
# 'location'
# 920
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SECTOR', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False, 'testPeriod': 'P2Y0M'}, 'regular': '-rank(ts_rank(mdl26_peg_smartestimate_fy1,3822))-ts_rank(ts_decay_exp_window(fnd28_astut_value_08401a,3822),3822) '}
# <Response [401]>
# 'location'
# 921
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SECTOR', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False, 'testPeriod': 'P2Y0M'}, 'regular': '-rank(ts_rank(mdl26_peg_smartestimate_fy1,3822))-ts_rank(ts_decay_exp_window(fnd28_a_value_08346,3822),3822) '}
# <Response [401]>
# 'location'
# 922
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SECTOR', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False, 'testPeriod': 'P2Y0M'}, 'regular': '-rank(ts_rank(mdl26_peg_smartestimate_fy1,3822))-ts_rank(ts_decay_exp_window(fnd28_bsassetq_value_02140q,3822),3822) '}
# <Response [401]>
# 'location'
# 923
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SECTOR', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False, 'testPeriod': 'P2Y0M'}, 'regular': '-rank(ts_rank(mdl26_peg_smartestimate_fy1,3822))-ts_rank(ts_decay_exp_window(fnd28_bdea_value_03351a,3822),3822) '}
# <Response [401]>
# 'location'
# 924
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SECTOR', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False, 'testPeriod': 'P2Y0M'}, 'regular': '-rank(ts_rank(mdl26_peg_smartestimate_fy1,3822))-ts_rank(ts_decay_exp_window(fnd28_a_value_08326,3822),3822) '}
# <Response [401]>
# 'location'
# 925
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SECTOR', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False, 'testPeriod': 'P2Y0M'}, 'regular': '-rank(ts_rank(mdl26_peg_smartestimate_fy1,3822))-ts_rank(ts_decay_exp_window(fnd28_a_value_08371,3822),3822) '}
# <Response [401]>
# 'location'
# 926
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SECTOR', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False, 'testPeriod': 'P2Y0M'}, 'regular': '-rank(ts_rank(mdl26_peg_smartestimate_fy1,3822))-ts_rank(ts_decay_exp_window(fnd28_a_value_08316,3822),3822) '}
# <Response [401]>
# 'location'
# 927
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SECTOR', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False, 'testPeriod': 'P2Y0M'}, 'regular': '-rank(ts_rank(mdl26_peg_smartestimate_fy1,3822))-ts_rank(ts_decay_exp_window(fnd28_value_05480,3822),3822) '}
# <Response [401]>
# 'location'
# 928
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SECTOR', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False, 'testPeriod': 'P2Y0M'}, 'regular': '-rank(ts_rank(mdl26_peg_smartestimate_fy1,3822))-ts_rank(ts_decay_exp_window(fnd28_a_value_08301,3822),3822) '}
# <Response [401]>
# 'location'
# 929
# {'type': 'REGULAR', 'settings': {'instrumentType': 'EQUITY', 'region': 'GLB', 'universe': 'MINVOL1M', 'delay': 1, 'decay': 0, 'neutralization': 'SECTOR', 'truncation': 0.08, 'pasteurization': 'ON', 'unitHandling': 'VERIFY', 'nanHandling': 'OFF', 'language': 'FASTEXPR', 'visualization': False, 'testPeriod': 'P2Y0M'}, 'regular': '-rank(ts_rank(mdl26_peg_smartestimate_fy1,3822))-ts_rank(ts_decay_exp_window(fnd28_a_value_08366,3822),3822) '}
# <Response [401]>
# 'location'
